# %% [markdown]
# ### Chapter 3-1 Projec

# %% [markdown]
# # **Summary**
#
# | Task/ Question 	| Grade                     	|
# |----------------	|---------------------------	|
# | Task 1         	| Correct (1/1)             	|
# | Task 2         	| Partially Correct (0.5/1) 	|
# | Task 3         	| Correct (1/1)             	|
# | Task 4         	| Correct (1/1)             	|
# | Task 5         	| Incorrect (0/1)             	|
# | Task 6         	| Correct (1/1)             	|
# | Question 1       	| Correct (1/1)             	|
# | **Total**      	| **5.5/7 - 79%**         	|

# %% [markdown]
# ### 1. Read the data from the CSV file into a DataFrame and display the first five rows.

# %%
import pandas as pd

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Warning:</b> Variables polls_filepath and polls_df will run without error, but we should assign a more meaningful name that reflects the data that we are working with. Consider ramen_filepath and ramen_df, as "polls" is suggesting that we are working with polling data.
# </div>

# %%
# polls_filepath = 'C:/DATA/ramen-ratings.csv'
ramen_filepath  = 'ramen-ratings.csv'
ramen_df =pd.read_csv(ramen_filepath)

# %%
ramen_df.head(5)
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %% [markdown]
# ### 2.Create a histogram for the Stars column using the number of bins necessary to display the ratings for each quarter of a star.

# %%
stars_sorted=ramen_df.sort_values(by=['Stars'], ascending=[True])
stars_sorted
# Out:
#                Brand                                    Variety Style  \
# 555     Urban Noodle           Authentic Street Food Black Bean   Cup
# 796   Western Family               Beef Flavour Instant Noodles  Pack
# 2534     Kim Ve Wong  Jaopai Series: Vegetarian Instant Noodles  Bowl
# 561    Samyang Foods                    Honey & Cheese Big Bowl  Bowl
# 950            Azami                        Kimchee Noodle Soup   Cup
# ...              ...                                        ...   ...
# 346           Nissin                       Spicy Chikin Donburi  Bowl
# 1837         Indomie                     Mi Goreng Sate (Local)  Pack
# 350           Nissin                           Raoh Shoyu Ramen  Bowl
# 800              JML                   Spicy King Spicy Chicken  Pack
# 667           Nissin          Emergency Chikin Ramen Cup Noodle   Cup
#
#           Country  Stars
# 555            UK    0.0
# 796        Canada    0.0
# 2534       Taiwan    0.0
# ...

# %%
ramen_df.plot.hist(y='Stars', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### 3.Create a KDE plot for the Stars column.

# %%
ramen_df.plot.density(y='Stars')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 4.Create a bar plot that shows the average number of stars by ramen style. Hint: You’ll need to group the data before you plot it.

# %%
ramen_df.groupby('Style').agg('mean').plot.bar()
# Out:
# <AxesSubplot:xlabel='Style'>

# %% [markdown]
# #### 5.Create a bar plot that shows the total number of reviews for each ramen type.

# %%
ramen_df.groupby('Style')['Stars'].agg('count').plot.bar()
# Out:
# <AxesSubplot:xlabel='Style'>

# %% [markdown]
# ### 6. Create a bar plot that shows the highest score given to each ramen type.

# %%
ramen_df.groupby('Style').agg('max').plot.bar()
# Out:
# <AxesSubplot:xlabel='Style'>

# %% [markdown]
# ### Question: 1.What is the most common style of ramen?

# %%
ramen_df.groupby('Style')['Stars'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Stars'>
