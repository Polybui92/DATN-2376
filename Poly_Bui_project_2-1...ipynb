# %%
import pandas as pd

# %%
# store filepath location in varibale poll_filepath
polls_filepath = 'C:/DATA/president_polls_2016.csv'
#Read in csv file presidentail_polls_2016 as a dataframe using pandas
polls_df =pd.read_csv(polls_filepath)

# %%
# Set all columns to display
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 2. first five rows of data

# %%
polls_df.head(5)
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  samplesize  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+      2220.0
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B     26574.0
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-      2195.0
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B      3677.0
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-     16639.0
#
# ...

# %% [markdown]
# ### 3. last five rows of data.

# %%
polls_df.tail(5)
# Out:
#        cycle     branch        type                        matchup  \
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 12619      11/8/16  New Hampshire    7/9/2016  7/18/2016
# 12620      11/8/16      Wisconsin  10/21/2016  11/2/2016
# 12621      11/8/16       New York    8/7/2016  8/10/2016
# 12622      11/8/16       Virginia   9/30/2016  10/6/2016
# 12623      11/8/16      Wisconsin    6/9/2016  6/12/2016
#
#                           pollster grade  samplesize population  poll_wt  \
# 12619  University of New Hampshire    B+       469.0         lv      0.0
# ...

# %% [markdown]
# ### 4.Display statistical information for the numeric

# %%
polls_df.describe().T
# Out:
#                     count          mean          std           min  \
# cycle             12624.0   2016.000000     0.000000   2016.000000
# samplesize        12621.0   1148.216068  2630.647790     35.000000
# poll_wt           12624.0      0.255431     0.669326      0.000000
# rawpoll_clinton   12624.0     41.990860     7.727792     11.040000
# rawpoll_trump     12624.0     39.828710     7.877327      4.000000
# rawpoll_johnson    8397.0      7.381740     2.959274      0.000000
# rawpoll_mcmullin     90.0     24.004000     5.638641      9.000000
# adjpoll_clinton   12624.0     43.323005     7.095235     17.064950
# adjpoll_trump     12624.0     42.667719     6.948256      4.372936
# adjpoll_johnson    8397.0      4.655091     2.472636     -3.677883
# adjpoll_mcmullin     90.0     24.511497     5.174286     11.028320
# poll_id           12624.0  45910.899477  2864.536271  35362.000000
# question_id       12624.0  71591.326046  4699.401001  47244.000000
#
# ...

# %% [markdown]
# ### 5.number of unique values for each column

# %%
polls_df.nunique()
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %% [markdown]
# ### 6.rows where the country is Vietnam

# %%
polls_df.query('state == "Vietnam"')
# Out:
# Empty DataFrame
# Columns: [cycle, branch, type, matchup, forecastdate, state, startdate, enddate, pollster, grade, samplesize, population, poll_wt, rawpoll_clinton, rawpoll_trump, rawpoll_johnson, rawpoll_mcmullin, adjpoll_clinton, adjpoll_trump, adjpoll_johnson, adjpoll_mcmullin, multiversions, url, poll_id, question_id, createddate, timestamp]
# Index: []

# %% [markdown]
# ### 7.Display only the Brand and Style columns

# %%
polls_df[['branch','state']]
# Out:
#           branch          state
# 0      President           U.S.
# 1      President           U.S.
# 2      President           U.S.
# 3      President           U.S.
# 4      President           U.S.
# ...          ...            ...
# 12619  President  New Hampshire
# 12620  President      Wisconsin
# 12621  President       New York
# 12622  President       Virginia
# 12623  President      Wisconsin
#
# [12624 rows x 2 columns]

# %% [markdown]
# ### 8.Country column

# %%
polls_df[['state']]
# Out:
#                state
# 0               U.S.
# 1               U.S.
# 2               U.S.
# 3               U.S.
# 4               U.S.
# ...              ...
# 12619  New Hampshire
# 12620      Wisconsin
# 12621       New York
# 12622       Virginia
# 12623      Wisconsin
#
# [12624 rows x 1 columns]

# %% [markdown]
# ### 9. data after it has been sorted by the Stars column from high values to low values

# %%
polls_df.sort_values(by=['startdate'], ascending=[False])
# Out:
#        cycle     branch        type                        matchup  \
# 10862   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6718    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 11203   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 2105    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2801    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 3981    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4013    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 12439   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8231    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 4023    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
#
#       forecastdate     state  startdate    enddate          pollster grade  \
# 10862      11/8/16  Kentucky   9/9/2016  9/22/2016             Ipsos    A-
# ...

# %% [markdown]
# ### 10.replace “USA” with “United States”

# %%
rename_state_dictionary = {'United States': 'USA'}
polls_df['state'].replace(rename_state_dictionary, inplace=True)
                                             
polls_df[polls_df['state'] == 'US']
polls_df.head(5)
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  samplesize  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+      2220.0
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B     26574.0
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-      2195.0
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B      3677.0
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-     16639.0
#
# ...

# %% [markdown]
# ### Question

# %%
### I think I use the wrong file but I can't find out where is remen_ratings.csv.
